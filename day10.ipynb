# %%
# Image Processing And Computer System
# image size is 8 bit(0-255)


# Image types - 1)True colour-it use by RGB,CMYK,HSV,BGR
#               2)Grey Scale
#               3)Binary

# %%
import cv2

# %%
import skimage as ski

# %%
import matplotlib.pyplot as plt

# %%
img = cv2.imread('sh2.JPEG')
cv2.imshow('',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img
# Out:
# array([[[34, 24, 54],
#         [34, 24, 54],
#         [34, 24, 54],
#         ...,
#         [29, 19, 49],
#         [29, 19, 49],
#         [29, 19, 49]],
#
#        [[34, 23, 55],
#         [34, 23, 55],
#         [34, 23, 55],
#         ...,
#         [29, 19, 49],
#         [29, 19, 49],
#         [29, 19, 49]],
#
#        [[35, 24, 56],
#         [35, 24, 56],
#         [35, 24, 56],
#         ...,
#         [30, 20, 50],
#         [30, 20, 50],
#         [30, 20, 50]],
#
#        ...,
#
#        [[16, 16, 30],
#         [16, 16, 30],
#         [16, 16, 30],
#         ...,
#         [ 0,  0,  1],
#         [ 0,  0,  1],
#         [ 0,  0,  1]],
#
#        [[19, 17, 36],
#         [19, 17, 36],
#         [19, 17, 36],
#         ...,
#         [ 0,  0,  1],
#         [ 0,  0,  1],
#         [ 0,  0,  1]],
#
#        [[21, 18, 40],
#         [21, 18, 40],
#         [21, 18, 40],
#         ...,
#         [ 0,  0,  1],
#         [ 0,  0,  1],
#         [ 0,  0,  1]]], dtype=uint8)

# %%
img1 = plt.imread('sh2.jpeg')
plt.imshow(img1)

# %%
plt.bar(55,5,5)
# Out:
# <BarContainer object of 1 artists>
